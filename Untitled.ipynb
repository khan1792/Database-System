# %%
import gmaps
import matplotlib.pyplot as plt
import pandas as pd
import MySQLdb
import gmplot
gmaps.configure(api_key='AIzaSyBZRH9rn8MiB4Q777r2pxeI5xBl4dCR7Zo')
import seaborn as sns
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-219-3e74aaca859d> in <module>
#       6 gmaps.configure(api_key='AIzaSyBZRH9rn8MiB4Q777r2pxeI5xBl4dCR7Zo')
#       7 import seaborn as sns
# ----> 8 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
champaign = (40.1112, -88.243)
gmaps.figure(center=champaign, zoom_level=15)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
db = MySQLdb.connect(host="127.0.0.1",  
                     user="root",         
                     passwd="database", 
                     db="cs411") 

def attribute(data, attri, c):
    cur = db.cursor()
    cur.execute("SELECT * FROM tidychampaign")
    champaign = pd.read_sql('SELECT * FROM tidychampaign', con=db)
    geo = pd.read_sql('SELECT * FROM geo', con=db)
    data = pd.merge(geo, champaign,
                    on='GEOID',
                    how='inner')
    plt.scatter(data['lat'], data['lon'], s=data[race]/3, c = c)

# %%
plt.figure(figsize=(20,20))
race(data, 'White', 'lightblue')
race(data, 'Black', 'green')
race(data, 'Asian', 'pink')

# %%
plt.figure(figsize=(20,20))
race(data, 'Young', 'lightblue')
race(data, 'Middle', 'green')
race(data, 'Old', 'pink')

# %%
plt.figure(figsize=(20,20))
race(data, 'Female', 'pink')
race(data, 'Male', 'lightblue')
